# %%
# import desire.utils.data_loader as dl
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

execfile("utils/data_loader.py")

# %%
seq_length = 20
batch_size = 10
max_num_obj = 60
height = 1982
widht = 1334
learning_rate = 0.005
latent_size = 48
k_traj = 7
radial_bin = 6
angular_bin = 1
strides = 1

data_loader = DataLoader(10, 8, 60, 5)
# Out:
# 13335
# 14090
# 14558
# 14558
# 14558

# %%
xval, yval, dval = data_loader.next_batch()
data_loader.reset_batch_pointer()
print(np.asarray(xval).shape)
xval = np.asarray(xval)
yval = np.asarray(yval)
vals = np.hstack([xval, yval])
print(vals.shape)
a = vals[:, :, 2, 1:]
# print(a.reshape(:, 16*2).shape)
print("-----")
print(xval[0, :, 2, 1:])
print(yval[0, :, 2, 1:])
# Out:
# (10, 8, 60, 3)
# (10, 16, 60, 3)
# -----
# [[ 757.   918.5]
#  [ 757.   918.5]
#  [ 757.   918.5]
#  [ 759.   918.5]
#  [ 759.   918.5]
#  [ 759.   918.5]
#  [ 761.   918.5]
#  [ 761.   918.5]]
# [[ 757.   918.5]
#  [ 757.   918.5]
#  [ 759.   918.5]
#  [ 759.   918.5]
#  [ 759.   918.5]
#  [ 761.   918.5]
#  [ 761.   918.5]
#  [ 761.   918.5]]

# %%
xval = np.asarray(xval)

# %%
plt.figure()
print(vals[0, :, 2, 2])
plt.plot(vals[0, :, :, 2], vals[0, :, :, 1])
plt.show()
# Out:
# [ 918.5  918.5  918.5  918.5  918.5  918.5  918.5  918.5  918.5  918.5
#   918.5  918.5  918.5  918.5  918.5  918.5]

# %%
# Size of the encoding layer (the hidden layer)
encoding_dim = 8 # feel free to change this value

input_size = 16*60*2

# Input and target placeholders
inputs_ = tf.placeholder(tf.float32, (None, 16, 60, 2), name="inputs")
inputs = tf.reshape(inputs_, shape=[-1, input_size])
targets_ = tf.placeholder(tf.float32, (None, 16, 60, 2), name="targets")
targets = tf.reshape(targets_, shape=[-1, input_size])

# Output of hidden layer, single fully connected layer here with ReLU activation
encoded = tf.layers.dense(inputs, 8, activation=tf.nn.relu)

# Output layer logits, fully connected layer with no activation
logits = tf.layers.dense(encoded, input_size, activation=None)
# Sigmoid output from logits
decoded = tf.sigmoid(logits, name = "decoded")

# Sigmoid cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=targets)
# Mean of the loss
cost = tf.reduce_mean(loss)

# Adam optimizer
opt = tf.train.AdamOptimizer().minimize(cost)

# %%
# Create the session
sess = tf.Session()

# %%
epochs = 20
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(data_loader.num_batches):
        batch = data_loader.next_batch()
        vals = np.hstack([batch[0], batch[1]])
        vals = vals[:, :, :, 1:]
        feed = {inputs_: vals, targets_: vals}
        batch_cost, _ = sess.run([cost, opt], feed_dict=feed)

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# ('Epoch: 1/20...', 'Training loss: 773.6655')
# ('Epoch: 1/20...', 'Training loss: -1222.4021')
# ('Epoch: 1/20...', 'Training loss: -3192.6128')
# ('Epoch: 1/20...', 'Training loss: -5326.1367')
# ('Epoch: 1/20...', 'Training loss: -8080.0459')
# ('Epoch: 1/20...', 'Training loss: -11202.1016')
# ('Epoch: 1/20...', 'Training loss: -14723.3398')
# ('Epoch: 1/20...', 'Training loss: -18949.3613')
# ('Epoch: 1/20...', 'Training loss: -23756.8008')
# ('Epoch: 1/20...', 'Training loss: -29172.3203')
# ('Epoch: 1/20...', 'Training loss: -35069.3555')
# ('Epoch: 1/20...', 'Training loss: -28907.9336')
# ('Epoch: 1/20...', 'Training loss: -36860.2617')
# ('Epoch: 1/20...', 'Training loss: -47158.1680')
# ('Epoch: 1/20...', 'Training loss: -54423.3438')
# ('Epoch: 1/20...', 'Training loss: -62550.4648')
# ('Epoch: 1/20...', 'Training loss: -71340.9688')
# ('Epoch: 1/20...', 'Training loss: -80243.1641')
# ('Epoch: 1/20...', 'Training loss: -89528.9922')
# ...

# %%
syntax_filter_height = 5
syntax_filter_width = 5
in_channels = 2*2
out_channels = 16
rnn_size = 48
vae_input_size = 48
def define_weights():
        ''' Define Model's weights'''
        # Weights adn Biases for hidden layer and output layer
        # TODO:Make sure you learn the dimensionalities!!!!!
        weights, biases = {}, {}

        with tf.variable_scope("semantic_context1"):
            weights["syntax_w1"] = tf.Variable(tf.truncated_normal( \
                [syntax_filter_height,
                 syntax_filter_width,
                 2*in_channels,
                 out_channels],
                stddev=0.1))
            biases["syntax_b1"] = tf.Variable(tf.random_normal( \
                [out_channels]))

        with tf.variable_scope("semantic_context2"):
            weights["syntax_w2"] = tf.Variable(tf.truncated_normal( \
                [syntax_filter_height,
                 syntax_filter_width,
                 out_channels,
                 2*out_channels],
                stddev=0.1))
            biases["syntax_b2"] = tf.Variable(tf.random_normal( \
                [2*out_channels]))

        with tf.variable_scope("semantic_context3"):
            weights["syntax_w3"] = tf.Variable(tf.truncated_normal( \
                [syntax_filter_height,
                 syntax_filter_width,
                 2*out_channels,
                 2*out_channels],
                stddev=0.1))
            biases["syntax_b3"] = tf.Variable(tf.random_normal( \
                [2*out_channels]))

        with tf.variable_scope("temporal_weights"):
            # This is the filter window
            weights["temporal_w"] = tf.Variable(tf.truncated_normal( \
                [-1, filter_width, in_channels, out_channels],
                stddev=0.1))
            biases["temporal_b"] = tf.Variable(tf.random_normal( \
                [-1, out_channels]))

        with tf.variable_scope("temporal_weights_y"):
            # This is the filter window
            weights["temporal_w_y"] = tf.Variable(tf.truncated_normal( \
                [1, in_channels, out_channels],
                stddev=0.1))
            biases["temporal_b_y"] = tf.Variable(tf.random_normal( \
                [out_channels]))

        with tf.variable_scope("velocity_weights"):
            # This is the filter window
            weights["velocity_w"] = tf.Variable(tf.truncated_normal( \
                [filter_width, 2, 2],
                stddev=0.1))
            weights["velocityp_w"] = tf.Variable(tf.truncated_normal( \
                [2, out_channels],
                stddev=0.1))
            biases["velocityp_b"] = tf.Variable(tf.random_normal( \
                [out_channels]))

        with tf.variable_scope("hidden_enc_weights"):
            weights["w_hidden_enc1"] = tf.Variable(tf.random_normal( \
                [2*rnn_size, vae_input_size]))
            biases["b_hidden_enc1"] = tf.Variable(tf.random_normal( \
                [vae_input_size]))

        with tf.variable_scope("mu_weights"):
            weights["w_mu"] = tf.Variable(tf.random_normal( \
                [vae_input_size, z_dim]))
            biases["b_mu"] = tf.Variable(tf.zeros( \
                [z_dim]))

        with tf.variable_scope("generation_weights_1"):
            weights["w_generation_1"] = tf.Variable(tf.random_normal( \
                [z_dim + rnn_size, vae_input_size]))
            biases["b_generation_1"] = tf.Variable(tf.zeros( \
                [vae_input_size]))

        with tf.variable_scope("generation_weights_2"):
            weights["w_generation_2"] = tf.Variable(tf.random_normal( \
                [vae_input_size, rnn_size]))
            biases["b_generation_2"] = tf.Variable(tf.zeros( \
                [rnn_size]))

        with tf.variable_scope("sigma_weights"):
            weights["w_sigma"] = tf.Variable(tf.random_normal( \
                [vae_input_size, z_dim]))
            biases["b_sigma"] = tf.Variable(tf.zeros( \
                [z_dim]))

        with tf.variable_scope("post_vae_weights"):
            weights["w_post_vae"] = tf.Variable(tf.random_normal( \
                [vae_input_size, rnn_size]))
            biases["b_post_vae"] = tf.Variable(tf.zeros( \
                [rnn_size]))

        with tf.variable_scope("sample_reconstruction"):
            weights["reconstr_w"] = tf.Variable(tf.random_normal( \
                [rnn_size, 2]))
            biases["reconstr_b"] = tf.Variable(tf.zeros([2]))

        with tf.variable_scope("social_weights"):
            weights["social_w"] = tf.Variable(tf.random_normal( \
                [radial_bin*angular_bin*rnn_size, rnn_size]))
            biases["social_b"] = tf.Variable(tf.zeros([rnn_size]))

        return weights, biases

# %%
input_data = tf.placeholder(
            tf.float32,
            shape=[batch_size, max_num_obj, seq_length, input_size],
            name="input_data"
        )

target_data = tf.placeholder(
            tf.float32,
            shape=[batch_size, max_num_obj, 2*seq_length, input_size],
            name="target_data"
        )

reference_filename = tf.placeholder(
            tf.float32,
            shape=[batch_size, 1, height, width, 4],
            name="reference_filename"
        )

features_batch = tf.placeholder(
            tf.float32,
            shape=[batch_size, 2*seq_length, max_num_obj, height/2, width/2, 2],
            name="features_batch"
        )

learning_rate = tf.Variable(
            learning_rate,
            trainable=False,
            name="learning_rate"
        )

z = tf.placeholder(
            tf.float32,
            shape=[None, z_dim],
            name="z"
        )

grid_data = tf.placeholder(
            tf.float32,
            [
                batch_size,
                2*seq_length,
                max_num_obj,
                k_traj,
                max_num_obj,
                radial_bin*angular_bin
            ],
            name="grid_data"
        )

output_size = seq_length * 2
weights, biases = define_weights()



# 1D Temporal Convolution
temporal_shape = self.input_data.get_shape().as_list()
temporal_shape[-1] = temporal_shape[-1] - 1
temporal_input = tf.slice(
    self.input_data,
    [0, 0, 0, 0],
    temporal_shape
)
temporal_ids = self.input_data[:, :, :, :1] # make sure its correct id is index 0 not 2 !!!
temporal_ids = [[
    tf.split(temporal_ids[y][i], self.seq_length, 0)
    for i in range(self.max_num_obj)] for y in range(self.batch_size)]

with tf.variable_scope("temporal_convolution"):
    self.temporal_input = [tf.nn.relu(tf.add( \
        tf.nn.conv1d(
            temporal_input[i], weights["temporal_w"],
            self.strides,
            padding='SAME'
        ),
        biases["temporal_b"])) for i in range(self.batch_size)]
    
temporal_shape_y = target_data.get_shape().as_list()
temporal_shape_y[-1] = temporal_shape_y[-1] - 1
temporal_input_y = tf.slice(
    target_data,
    [0, 0, 0, 0],
    temporal_shape_y
)
temporal_ids_y = target_data[:, :, :, :1]
temporal_ids_y = [
    tf.split(0, 2*seq_length, temporal_ids_y[i])
    for i in xrange(max_num_obj)]

with tf.variable_scope("temporal_convolution_y"):
    self.temporal_input_y = [tf.nn.relu(tf.add( \
        tf.nn.conv1d(
            temporal_input_y[i], weights["temporal_w_y"],
            strides,
            padding='SAME'
        ),
        biases["temporal_b_y"])) for i in range(self.batch_size)]

# %%
num_layers = 1
# Encoder
with tf.variable_scope("gru_cell"):
    gru_cell = tf.nn.rnn_cell.GRUCell(rnn_size)
    cells = tf.nn.rnn_cell.MultiRNNCell(
        [gru_cell]*num_layers,
        state_is_tuple=False
    )

with tf.variable_scope("gru_y_cell"):
    gru_cell_y = tf.nn.rnn_cell.GRUCell(rnn_size)
    cells_y = tf.nn.rnn_cell.MultiRNNCell(
        [gru_cell_y]*num_layers,
        state_is_tuple=False
    )

with tf.variable_scope("gru_y_cell"):
    gru_cell_samples = tf.nn.rnn_cell.GRUCell(rnn_size)
    cells_s = tf.nn.rnn_cell.MultiRNNCell(
        [gru_cell_samples]*num_layers,
        state_is_tuple=False
    )

with tf.variable_scope("gru_y_cell"):
    gru_cell_decoder_two = tf.nn.rnn_cell.GRUCell(rnn_size)
    cells_dtwo = tf.nn.rnn_cell.MultiRNNCell(
        [gru_cell_decoder_two]*num_layers,
        state_is_tuple=False
    )

# Define GRU states for each pedestrian
with tf.variable_scope("gru_states"):
    gru_states = tf.zeros(
        [max_num_obj, cells.state_size],
        name="gru_states"
    )
    enc_state_x = tf.split(
        0, max_num_obj, gru_states
    )
    h_of_x = tf.split(
        0, max_num_obj, gru_states
    )

with tf.variable_scope("gru_states_y"):
    gru_states_y = tf.zeros(
        [max_num_obj, cells_y.state_size],
        name="gru_states_y"
    )
    enc_state_y = tf.split(
        0, max_num_obj, gru_states_y
    )
    h_of_y = tf.split(
        0, max_num_obj, gru_states_y
    )


with tf.variable_scope("feature_pooling"):
    f_pool = \
        tf.zeros([max_num_obj, 7, seq_length, 2*out_channels])
    feature_pooling = \
        tf.split(0, max_num_obj, f_pool)
    feature_pooling = [tf.squeeze(_input, [0]) for _input in feature_pooling]

# Define hidden output states for each pedestrian ??
with tf.variable_scope("output_states"):
    output_states = \
        tf.split(0, max_num_obj, \
            tf.zeros([
                max_num_obj,
                k_traj,
                cells.output_size
            ]))
    output_states = [
        tf.squeeze(output_states[i], [0])
        for i in xrange(len(output_states))]
    output_states = [
        tf.split(0, k_traj, output_states[i])
        for i in xrange(len(output_states))]
# List of tensors each of shape args.maxNumPedsx3 corresponding to
# each frame in the sequence
with tf.name_scope("frame_data_tensors"):
    frame_data = [tf.squeeze(input_, [0]) \
        for input_ in tf.split(0, max_num_obj, temporal_input)]

with tf.name_scope("frame_data_tensors_y"):
    frame_data_y = [tf.squeeze(input_, [0]) \
        for input_ in tf.split(0, max_num_obj, temporal_input_y)]

# Cost
with tf.name_scope("cost_related_stuff"):
    cost = tf.constant(0.0, name="cost")
    counter = tf.constant(0.0, name="counter")
    increment = tf.constant(1.0, name="increment")

# Containers to store output distribution parameters
with tf.name_scope("distribution_parameters_stuff"):
    initial_output = \
        tf.split(0, max_num_obj, \
            tf.zeros([max_num_obj, output_size]))

# Tensor to represent non-existent ped
with tf.name_scope("non_existent_obj_stuff"):
    nonexistent_obj = tf.constant(0.0, name="zero_obj")

with tf.name_scope("grid_frame_data_tensors"):
    # This would contain a list of tensors each of shape
    # MNP x MNP x (GS**2) encoding the mask
    grid_data_split = tf.split(0, 2*seq_length, grid_data)
    grid_frame_data = [tf.squeeze(input_, [0]) for input_ in grid_data_split]

with tf.name_scope("decoder_inputs"):
    decoder_inputs = tf.split(
        0,
        max_num_obj,
        tf.zeros([max_num_obj, k_traj, 2*seq_length, rnn_size]))
    decoder_inputs = [
        tf.squeeze(decoder_inputs[i], [0])
        for i in xrange(max_num_obj)]
    decoder_inputs = [
        tf.split(0, k_traj, decoder_inputs[i])
        for i in xrange(max_num_obj)]
    decoder_inputs = [
        [
            tf.squeeze(decoder_inputs[i][j], [0])
            for j in xrange(k_traj)]
        for i in xrange(max_num_obj)]

with tf.name_scope("sample_reconstr"):
    sample_reconstr = tf.split(
        0,
        max_num_obj,
        tf.zeros([max_num_obj, k_traj, 2*seq_length, 2]))
    sample_reconstr = [
        tf.squeeze(sample_reconstr[i], [0])
        for i in xrange(len(sample_reconstr))]
    sample_reconstr = [
        tf.split(0, k_traj, sample_reconstr[i])
        for i in xrange(len(sample_reconstr))]
    sample_reconstr = [
        [
            tf.squeeze(sample_reconstr[i][j], [0])
            for j in xrange(k_traj)]
        for i in xrange(max_num_obj)]
    sample_reconstr = [
        [
            tf.split(0, 2*seq_length, sample_reconstr[i][j])
            for j in xrange(k_traj)]
        for i in xrange(max_num_obj)]
# sample_reconstr.append([])

for obj in xrange(0, args.max_num_obj):
    obj_id = temporal_ids[obj][0][0]
    pooling_list = []
    with tf.name_scope("extract_input_obj"):
        spatial_input_x = tf.split(
            0, seq_length,
            frame_data[obj]
        )
        spatial_input_y = tf.split(
            0, 2*seq_length,
            frame_data_y[obj]
        )

    with tf.variable_scope("encoding_operations_x", \
                reuse=True if obj > 0 else None):
        _, enc_state_x[obj] = \
            rnn.rnn(cells, spatial_input_x, dtype=dtypes.float32)

    with tf.variable_scope("encoding_operations_y", \
                reuse=True if obj > 0 else None):
        _, enc_state_y[obj] = \
            rnn.rnn(cells_y, spatial_input_y, dtype=dtypes.float32)

    with tf.name_scope("concatenate_embeddings"):
        # Concatenate the summaries c1 and c2
        complete_input = tf.concat(
            1,
            [enc_state_x[obj], enc_state_y[obj]]
        )

    # Convolutional VAE
    # fc layer
    with tf.variable_scope("fc_c"):
        vae_inputs = \
            tf.nn.relu( \
                tf.nn.xw_plus_b( \
                    complete_input, weights["w_hidden_enc1"], biases["b_hidden_enc1"]))

    # Encode our data into z and return the mean and covariance
    # =============================== Q(z|X) ======================================
    with tf.variable_scope("recognition", reuse=True if obj > 0 else None):
        z_mu = tf.nn.xw_plus_b(vae_inputs, weights["w_mu"], biases["b_mu"])
        z_logvar = tf.nn.xw_plus_b(vae_inputs, weights["w_sigma"], biases["b_sigma"])
        eps = [tf.random_normal(shape=tf.shape(z_mu)) for k in xrange(k_traj)]
        z_sample = [z_mu + tf.exp(z_logvar / 2) * eps[k] for k in xrange(k_traj)]

    # =============================== P(X|z) ======================================
    with tf.variable_scope("generation", reuse=True if obj > 0 else None):
        inputs = [
            tf.concat(1, values=[z_sample[k], enc_state_y[obj]])
            for k in xrange(k_traj)]
        hidden = [
            tf.nn.relu(
                tf.nn.xw_plus_b(
                    inputs[k], weights["w_generation_1"], biases["b_generation_1"]))
            for k in xrange(k_traj)]
        logits = [
            tf.nn.xw_plus_b(
                hidden[k],
                weights["w_generation_2"],
                biases["b_generation_2"])
            for k in xrange(k_traj)]
        # prob = tf.nn.sigmoid(logits)
        x_samples = logits

    # fc layer
    with tf.variable_scope("fc_softmax"):
        multipl = [
            tf.add(
                tf.matmul(
                    x_samples[k], weights["w_post_vae"]),
                biases["b_post_vae"])
            for k in xrange(k_traj)]
        # multipl = tf.nn.relu(multipl)
        multipl = tf.nn.softmax(multipl)

    with tf.variable_scope("rnn_decoder"):
        # outputs = [[] for k in xrange(k_traj)]
        prev = None
        decoder_inputs[obj] = [
            tf.pad(tf.mul(multipl[k], enc_state_x[obj]), [[0, 39], [0, 0]], "CONSTANT")
            for k in xrange(k_traj)]
        
        
# Sigmoid cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=targets)
# Mean of the loss
cost = tf.reduce_mean(loss)

# Adam optimizer
opt = tf.train.AdamOptimizer().minimize(cost)
